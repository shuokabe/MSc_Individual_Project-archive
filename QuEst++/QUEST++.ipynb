# %%
# !pip install scikit-learn==0.15.2
# Out:
# ...
#      |████████████████████████████████| 7.0MB 36.7MB/s
# ...
#   Created wheel for scikit-learn: filename=scikit_learn-0.15.2-cp27-cp27mu-linux_x86_64.whl size=7076106 sha256=5fe6880263e8f55dbea90d7ee2f9988a52721e80a7dbe9dd4111197c771bef22
#   Stored in directory: /root/.cache/pip/wheels/46/d5/2b/b14351a6c82c2a46d5350bf52106b254c4cde97c1ffad7f43a
# Successfully built scikit-learn
# ERROR: mlxtend 0.14.0 has requirement scikit-learn>=0.18, but you'll have scikit-learn 0.15.2 which is incompatible.
# ERROR: fancyimpute 0.4.3 has requirement scikit-learn>=0.19.1, but you'll have scikit-learn 0.15.2 which is incompatible.
# ERROR: imbalanced-learn 0.4.3 has requirement scikit-learn>=0.20, but you'll have scikit-learn 0.15.2 which is incompatible.
# ERROR: yellowbrick 0.9.1 has requirement scikit-learn>=0.20, but you'll have scikit-learn 0.15.2 which is incompatible.
# ERROR: umap-learn 0.3.9 has requirement scikit-learn>=0.16, but you'll have scikit-learn 0.15.2 which is incompatible.
# ...

# %%
import sklearn # 0.20.3 initially 
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.15.2.

# %%
# !git clone https://github.com/ghpaetzold/questplusplus.git
# Out:
# Cloning into 'questplusplus'...
# remote: Enumerating objects: 2475, done.
# remote: Total 2475 (delta 0), reused 0 (delta 0), pack-reused 2475
# Receiving objects: 100% (2475/2475), 129.99 MiB | 17.25 MiB/s, done.
# Resolving deltas: 100% (1507/1507), done.
# Checking out files: 100% (613/613), done.

# %%
# !cp customize_scorer.py questplusplus/learning/src/

# %% [markdown]
# # The baseline model

# %%
cd questplusplus/
# Out:
# /content/questplusplus

# %%
# Transfer data
# !cp ../quest_baseline.training learning/data/features/
# !cp ../train.mqm learning/data/features/

#!cp ../quest_baseline.dev learning/data/features/
#!cp ../dev.mqm learning/data/features/

# !cp ../quest_baseline.test learning/data/features/
# !cp ../test.mqm learning/data/features/

# %%
# !cp ../svr_baseline.cfg learning/config/

# %%
cd learning/
# Out:
# /content/questplusplus/learning

# %%
# !python src/learn_model.py config/svr_baseline.cfg > log-quest_baseline.txt 2>&1

# %%
# !cat log-quest_baseline.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    1.9s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
from google.colab import files
files.download('log-quest_baseline.txt')

# %% [markdown]
# # With visual features

# %%
# /content/questplusplus
cd ..
# Out:
# /content/questplusplus

# %%
# !cp ../quest.train_2 learning/data/features/
# !cp ../quest.train_5 learning/data/features/
# !cp ../quest.train_10 learning/data/features/
# !cp ../quest.train_1 learning/data/features/
# !cp ../quest.train_3 learning/data/features/
#!cp ../train.mqm learning/data/features/

# !cp ../quest.test_2 learning/data/features/
# !cp ../quest.test_5 learning/data/features/
# !cp ../quest.test_10 learning/data/features/
# !cp ../quest.test_1 learning/data/features/
# !cp ../quest.test_3 learning/data/features/
#!cp ../test.mqm learning/data/features/

# %%
# !cp ../svr_vis_2.cfg learning/config/
# !cp ../svr_vis_5.cfg learning/config/
# !cp ../svr_vis_10.cfg learning/config/
# !cp ../svr_vis_1.cfg learning/config/
# !cp ../svr_vis_3.cfg learning/config/

# %%
cd learning/
# Out:
# /content/questplusplus/learning

# %% [markdown]
# ## WIth 2 visual features

# %%
# !python src/learn_model.py config/svr_vis_2.cfg > log-quest_vis_2.txt 2>&1

# %%
# !cat log-quest_vis_2.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.0s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
#from google.colab import files
files.download('log-quest_vis_2.txt')

# %% [markdown]
# ## With 5 components

# %%
# !python src/learn_model.py config/svr_vis_5.cfg > log-quest_vis_5.txt 2>&1
# !cat log-quest_vis_5.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.2s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
#from google.colab import files
files.download('log-quest_vis_5.txt')

# %% [markdown]
# ## With 10 components

# %%
# !python src/learn_model.py config/svr_vis_10.cfg > log-quest_vis_10.txt 2>&1
# !cat log-quest_vis_10.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.6s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
#from google.colab import files
files.download('log-quest_vis_10.txt')

# %% [markdown]
# ## With 1 component

# %%
# !python src/learn_model.py config/svr_vis_1.cfg > log-quest_vis_1.txt 2>&1
# !cat log-quest_vis_1.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    1.9s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
#from google.colab import files
files.download('log-quest_vis_1.txt')

# %% [markdown]
# ## WIth 3 components

# %%
# !python src/learn_model.py config/svr_vis_3.cfg > log-quest_vis_3.txt 2>&1
# !cat log-quest_vis_3.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.1s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 1.0, 'gamma': 0.01, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
#from google.colab import files
files.download('log-quest_vis_3.txt')

# %% [markdown]
# # With token

# %%
cd ..
# Out:
# /content/questplusplus

# %%
# !cp ../quest_bl_token_1.train learning/data/features/
# !cp ../quest_bl_token_5.train learning/data/features/
# !cp ../quest_bl_token_10.train learning/data/features/

# !cp ../quest_bl_token_1.test learning/data/features/
# !cp ../quest_bl_token_5.test learning/data/features/
# !cp ../quest_bl_token_10.test learning/data/features/

# !cp ../svr_bl_token_1.cfg learning/config/
# !cp ../svr_bl_token_5.cfg learning/config/
# !cp ../svr_bl_token_10.cfg learning/config/

# %%
cd learning/
# Out:
# /content/questplusplus/learning

# %%
# !python src/learn_model.py config/svr_bl_token_1.cfg > log-quest_bl_token_1.txt 2>&1

# %%
# !cat log-quest_bl_token_1.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.5s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
# !python src/learn_model.py config/svr_bl_token_5.cfg > log-quest_bl_token_5.txt 2>&1
# !cat log-quest_bl_token_5.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.3s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
# !python src/learn_model.py config/svr_bl_token_10.cfg > log-quest_bl_token_10.txt 2>&1
# !cat log-quest_bl_token_10.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.0s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
#from google.colab import files
files.download('log-quest_bl_token_1.txt') 
files.download('log-quest_bl_token_5.txt') 
files.download('log-quest_bl_token_10.txt')

# %% [markdown]
# # With token and visual features

# %%
cd ..
# Out:
# /content/questplusplus

# %%
# !cp ../quest_vis_token_1.train learning/data/features/
# !cp ../quest_vis_token_5.train learning/data/features/
# !cp ../quest_vis_token_10.train learning/data/features/

# !cp ../quest_vis_token_1.test learning/data/features/
# !cp ../quest_vis_token_5.test learning/data/features/
# !cp ../quest_vis_token_10.test learning/data/features/

# !cp ../svr_vis_token_1.cfg learning/config/
# !cp ../svr_vis_token_5.cfg learning/config/
# !cp ../svr_vis_token_10.cfg learning/config/

# %%
cd learning/
# Out:
# /content/questplusplus/learning

# %%
# !python src/learn_model.py config/svr_vis_token_1.cfg > log-quest_vis_token_1.txt 2>&1
# !cat log-quest_vis_token_1.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.7s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
# !python src/learn_model.py config/svr_vis_token_5.cfg > log-quest_vis_token_5.txt 2>&1
# !cat log-quest_vis_token_5.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.4s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.1, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
# !python src/learn_model.py config/svr_vis_token_10.cfg > log-quest_vis_token_10.txt 2>&1
# !cat log-quest_vis_token_10.txt
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/weight_boosting.py:27: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# INFO:root:Opening input files ...
# INFO:root:Scaling datasets...
# INFO:root:Tuning hyper-parameters for mae
# /usr/local/lib/python2.7/dist-packages/sklearn/grid_search.py:347: DeprecationWarning: Passing a loss function is deprecated and will be removed in 0.15. Either use strings or score objects. The relevant new parameter is called ''scoring''.
#   score_func=self.score_func)
# [Parallel(n_jobs=1)]: Done   1 jobs       | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:    2.2s finished
# INFO:root:Best parameters set found on development set:
# INFO:root:{'epsilon': 0.2, 'C': 10.0, 'gamma': 0.0001, 'kernel': 'rbf'}
# INFO:root:Tuning hyper-parameters for rmse
# ...

# %%
#from google.colab import files
files.download('log-quest_vis_token_1.txt') 
files.download('log-quest_vis_token_5.txt') 
files.download('log-quest_vis_token_10.txt')
